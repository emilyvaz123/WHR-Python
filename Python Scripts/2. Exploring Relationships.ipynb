# %% [markdown]
# # Exploring Relationships

# %% [markdown]
# # Table of Contents
#
# 1. Importing Libraries
# 2. Importing Dataframe
# 3. Creating Correlation Matrix Heatmap
# 4. Creating a Scatterplot
# 5. Creating a Pair Plot
# 6. Creating Categorical Plot
# 7. Exporting Dataframe

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# ## 2. Importing Dataframe

# %%
# Defining a path 
path = r'C:\Users\emily\OneDrive\Documents\Career Foundry 2022\Data Immersion\Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2Cleaned_dataset.csv'), index_col = False)

# %%
# Checking shape of dataframe 
df.shape
# Out:
# (1084, 12)

# %%
df
# Out:
#       Country Rank  Year      Country              Region  Happiness Score  \
# 0                1  2015  Switzerland      Western Europe            7.587
# 1                2  2015      Iceland      Western Europe            7.561
# 2                3  2015      Denmark      Western Europe            7.527
# 3                4  2015       Norway      Western Europe            7.522
# 4                5  2015       Canada       North America            7.427
# ...            ...   ...          ...                 ...              ...
# 1079           145  2021      Lesotho  Sub-Saharan Africa            3.512
# 1080           146  2021     Botswana  Sub-Saharan Africa            3.467
# 1081           147  2021       Rwanda  Sub-Saharan Africa            3.415
# 1082           148  2021     Zimbabwe  Sub-Saharan Africa            3.145
# 1083           149  2021  Afghanistan          South Asia            2.523
#
#       Economy (GDP per Capita)  Family (Social Support)  \
# ...

# %% [markdown]
# ## 3. Creating a Correlation Matrix Heatmap

# %%
# Creating a subset of the data 
df_sub = df[[ 'Country Rank', 'Year','Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
# Create a correlation matrix using pandas
df_sub.corr()
# Out:
#                                    Country Rank      Year  Happiness Score  \
# Country Rank                           1.000000 -0.026736        -0.989890
# Year                                  -0.026736  1.000000         0.044501
# Happiness Score                       -0.989890  0.044501         1.000000
# Economy (GDP per Capita)              -0.791157  0.025077         0.785445
# Family (Social Support)               -0.625852  0.040760         0.626874
# Health (Life Expectancy)              -0.735117  0.035648         0.732238
# Freedom (Life Choices)                -0.545278  0.174584         0.560347
# Trust (Government Corruption)         -0.314878 -0.101472         0.329565
# Generosity (Donations to Charity)     -0.117421 -0.140502         0.142387
# Dystopia Residual                     -0.458312  0.033441         0.470568
#
#                                    Economy (GDP per Capita)  \
# Country Rank                                      -0.791157
# ...

# %% [markdown]
# ### Create a correlation heatmap using matplotlib

# %%
plt.matshow(df_sub.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap
f = plt.figure(figsize=(10, 10)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_sub.shape[1]), df_sub.columns, fontsize=10, rotation=80) # x axis labels
plt.yticks(range(df_sub.shape[1]), df_sub.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=11) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### Create a correlation heatmap using seaborn

# %%
df_sub.columns
# Out:
# Index(['Country Rank', 'Year', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Family (Social Support)', 'Health (Life Expectancy)',
#        'Freedom (Life Choices)', 'Trust (Government Corruption)',
#        'Generosity (Donations to Charity)', 'Dystopia Residual'],
#       dtype='object')

# %%
# Create a subset excluding the "Country Rank", "Country", Year" and "Region" columns

sub = df[['Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
sub
# Out:
#       Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 0               7.587                     1.397                    1.350
# 1               7.561                     1.302                    1.402
# 2               7.527                     1.325                    1.361
# 3               7.522                     1.459                    1.331
# 4               7.427                     1.326                    1.323
# ...               ...                       ...                      ...
# 1079            3.512                     0.451                    0.731
# 1080            3.467                     1.099                    0.724
# 1081            3.415                     0.364                    0.202
# 1082            3.145                     0.457                    0.649
# 1083            2.523                     0.370                    0.000
#
#       Health (Life Expectancy)  Freedom (Life Choices)  \
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.
plt.title('Correlation Heatmap', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Discuss what the coefficients in the plot mean in terms of the relationships between the variables.
#
# Happiness Score being the independent variable in this analysis and the other six factors being the dependent variables.
# Relationships between the variables are as follows:
#
# With "Happiness Score": At 0.56 we see a medium-strong relationship with "Freedom (Life Choices)". This could be interpreted as the more freedom a population is given the happier they will be.
#
# With "Economy (GDP per Capita)": At 0.7 we see a strong relationship with "Health (Life Expectancy)". This could be interpreted as life expectancy within a nation continues to rise so will its economy.
#
# With "Family (Social Support)": At 0.62 we see a strong relationship with Health (Life Expectancy). This could be interpreted as the stronger relationship a population has with their family and loved ones we can expect to see an increase in life expectancy of indiviudals.
#
# With "Freedon "(Life Choices)": At 0.23 we see a weak relationship between Generosity (Donations to Charity). This could be interpreted as the less a population has the freedom to make choices the less they will be generous in donations to charities.
#
# With "Trust (Government Corruption)": At 0.2 we see a weak relationship between Health (Life Expectancy). This could be interpreted as a population has less trust in its government then life expectancy will also decrease.
#
# With "Generosity (Donations to Charity)": At -0.083 we see a weak negative relationship between Economy (GDP per Capita). This could be interpreted as the less generous a population is the less the economy will grow.

# %% [markdown]
# ## 4. Creating a Scatterplot

# %%
# Create a scatterplot for the "Happiness score" and "Economy (GDP per Capita)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Economy (GDP per Capita)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Family (Social Support)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Family (Social Support)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Health (Life Expectancy)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Health (Life Expectancy)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Trust (Government Corruption)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Trust (Government Corruption)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Generosity (Donations to Charity)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Generosity (Donations to Charity)', data = df)

# %% [markdown]
# We see a strong positive relationship between Happiness Score and the variables: 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)'. The variables 'Trust (Government Corruption)' and Generosity (Donations to Charity)' have a weak relationship with the Happiness Score.

# %% [markdown]
# ## 5. Create a Pair Plot

# %%
# Creating a subplot with strictly these variables for the pair plot 
sub_2 = sub[['Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
# Creating a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# Comment on the distribution of the variables and mark variables you’d like to explore further with an explanation of why.
#
# Varaibales to further explore:
#
# Happiness Score vs. Economy (GDP per Capita)
# Happiness Score vs. Family (Social Support)
# Happiness Score vs. Health (Life Expectancy)
# Happiness Score vs. Freedom (Life Choices)
# Happiness Score vs Trust (Government Corruption)
# Happiness Score vs Generosity (Donations to Charity)
#
# Economy (GDP per Capita) vs. Health (Life Expectancy)
# Economy (GDP per Capita) vs. Trust (Government Corruption)
# Economy (GDP per Capita) vs. Generosity (Donations to Charity)
#
# Family (Social Support) vs. Trust (Government Corruption)
# Family (Social Support) vs. Generosity (Donations to Charity)
#
# Health (Life Expectancy) vs. Economy (GDP per Capita)
# Health (Life Expectancy) vs. Family (Social Support)
# Health (Life Expectancy) vs. Trust (Government Corruption)
# Health (Life Expectancy) vs. Generosity (Donations to Charity)
#
# Freedom (Life Choices) vs. Trust (Government Corruption)
# Freedom (Life Choices) vs. Generosity (Donations to Charity)
#
# Trust (Government Corruption) vs. Economy (GDP per Capita)
# Trust (Government Corruption) vs. Family (Social Support)
# Trust (Government Corruption) vs. Health (Life Expectancy)
# Trust (Government Corruption) vs. Freedom (Life Choices)
# Trust (Government Corruption) vs. Generosity (Donations to Charity)
#
# Generosity(Donations to Charity) vs. Economy (GDP per Capita)
# Generosity(Donations to Charity) vs. Family (Social Support)
# Generosity(Donations to Charity) vs. Trust (Government Corruption)
#
# Dystopia Residual vs. Generosity (Donations to Charity)
# Dystopia Residual vs. Trust (Government Corruption)

# %% [markdown]
# ## 6. Creating a Categorical Plot

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the price ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['Happiness Score'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Count'>

# %%
# Creating a Happiness flag for Countries
df.loc[df['Happiness Score'] < 4, 'Happiness Status'] = 'Unhappy Country'
df.loc[(df['Happiness Score'] >= 4) & (df['Happiness Score'] < 6), 'Happiness Status'] = 'Somewhat Happy Country'
df.loc[df['Happiness Score'] >= 6, 'Happiness Status'] = 'Happy Country'

# %%
# Checking creation of Exclusion flag 

df['Happiness Status'].value_counts(dropna = False)
# Out:
# Somewhat Happy Country    621
# Happy Country             340
# Unhappy Country           123
# Name: Happiness Status, dtype: int64

# %%
df.columns
# Out:
# Index(['Country Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Generosity (Donations to Charity)',
#        'Dystopia Residual', 'Happiness Status'],
#       dtype='object')

# %%
# Creating a categorical plot in seaborn using the Happiness Status created above

sns.set(style="ticks")
g = sns.catplot(x="Country", y="Happiness Score", hue="Happiness Status", data=df)

# %% [markdown]
# This categorical plot displays that a majority of the countries in this study land within the "Somewhat Happy Country" status. We see a few of countries in the "Unhappy Country" status and the rest of the countries landing within the "Happy Country status.

# %% [markdown]
# Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.
#
# Questions:
#
# What factors contribute most to a countries happiness score?
#
# Per this exploratory analysis the factors that contribute most to a countries happiness are: Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy) and Freedom (Life Choices).

# %% [markdown]
# Define any hypotheses that you can at this point. You’ll be testing these later on.
#
# Hypothesis: If a country has high scores in Economy (GDP per Capita), Family (Social Support) and Health (Life Expectancy), this  will result in having high Happiness Scores.

# %% [markdown]
# ## 7. Exporting Dataframe

# %%
df.to_csv(os.path.join(path, 'Data', 'Prepared Data', '3Complete_dataset.csv'), index=False)
