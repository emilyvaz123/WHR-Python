# %% [markdown]
# # Table of Contents
#
# 1. Importing Libraries
# 2. Importing Dataframes
# 3. Merging Dataframes
# 4. Data Cleaning
# 5. Descriptive Statistics
# 6. Exporting Dataframe

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np 
import os

# %% [markdown]
# ## 2. Importing Dataframe

# %% [markdown]
# Defining a path for Dataframes

# %%
path = r'C:\Users\emily\OneDrive\Documents\Career Foundry 2022\Data Immersion\Achievement 6'

# %%
year15 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2015 Cleaned.csv'), index_col = False)

# %%
year16 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2016 Cleaned.csv'), index_col = False)

# %%
year17 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2017 Cleaned.csv'), index_col = False)

# %%
year18 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2018 Cleaned.csv'), index_col = False)

# %%
year19 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2019 Cleaned.csv'), index_col = False)

# %%
year20 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2020 Cleaned.csv'), index_col = False)

# %%
year21 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2021 Cleaned.csv'), index_col = False)

# %% [markdown]
# Checking shape of each dataframe before merging together

# %%
year15.shape
# Out:
# (158, 12)

# %%
year15.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2015  Switzerland  Western Europe            7.587
# 1     2  2015      Iceland  Western Europe            7.561
# 2     3  2015      Denmark  Western Europe            7.527
# 3     4  2015       Norway  Western Europe            7.522
# 4     5  2015       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.397                    1.350
# 1                     1.302                    1.402
# 2                     1.325                    1.361
# 3                     1.459                    1.331
# 4                     1.326                    1.323
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.941                   0.666
# 1                     0.948                   0.629
# 2                     0.875                   0.649
# 3                     0.885                   0.670
# ...

# %%
year16.shape
# Out:
# (157, 12)

# %%
year16.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2016      Denmark  Western Europe            7.526
# 1     2  2016  Switzerland  Western Europe            7.509
# 2     3  2016      Iceland  Western Europe            7.501
# 3     4  2016       Norway  Western Europe            7.498
# 4     5  2016      Finland  Western Europe            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.442                    1.164
# 1                     1.527                    1.145
# 2                     1.427                    1.183
# 3                     1.577                    1.127
# 4                     1.406                    1.135
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.795                   0.579
# 1                     0.863                   0.586
# 2                     0.867                   0.566
# 3                     0.796                   0.596
# ...

# %%
year17.shape
# Out:
# (155, 12)

# %%
year17.head()
# Out:
#    RANK  Year      Country           Region  Happiness Score  \
# 0     1  2017       Norway  Western Europe             7.537
# 1     2  2017      Denmark  Western Europe             7.522
# 2     3  2017      Iceland  Western Europe             7.504
# 3     4  2017  Switzerland  Western Europe             7.494
# 4     5  2017      Finland  Western Europe             7.469
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.616                    1.534
# 1                     1.482                    1.551
# 2                     1.481                    1.611
# 3                     1.565                    1.517
# 4                     1.444                    1.540
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.797                   0.635
# 1                     0.793                   0.626
# 2                     0.834                   0.627
# 3                     0.858                   0.620
# ...

# %%
year18.shape
# Out:
# (156, 12)

# %%
year18.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2018      Finland  Western Europe            7.632
# 1     2  2018       Norway  Western Europe            7.594
# 2     3  2018      Denmark  Western Europe            7.555
# 3     4  2018      Iceland  Western Europe            7.495
# 4     5  2018  Switzerland  Western Europe            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# ...

# %%
year19.shape
# Out:
# (156, 12)

# %%
year19.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2019      Finland  Western Europe            7.769
# 1     2  2019      Denmark  Western Europe            7.600
# 2     3  2019       Norway  Western Europe            7.554
# 3     4  2019      Iceland  Western Europe            7.494
# 4     5  2019  Netherlands  Western Europe            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.340                    1.587
# 1                     1.383                    1.573
# 2                     1.488                    1.582
# 3                     1.380                    1.624
# 4                     1.396                    1.522
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.986                   0.596
# 1                     0.996                   0.592
# 2                     1.028                   0.603
# 3                     1.026                   0.591
# ...

# %%
year20.shape
# Out:
# (153, 12)

# %%
year20.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2020      Finland  Western Europe            7.809
# 1     2  2020      Denmark  Western Europe            7.646
# 2     3  2020  Switzerland  Western Europe            7.560
# 3     4  2020      Iceland  Western Europe            7.504
# 4     5  2020       Norway  Western Europe            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.285                    1.500
# 1                     1.327                    1.503
# 2                     1.391                    1.472
# 3                     1.327                    1.548
# 4                     1.424                    1.495
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.961                   0.662
# 1                     0.979                   0.665
# 2                     1.041                   0.629
# 3                     1.001                   0.662
# ...

# %%
year21.shape
# Out:
# (149, 12)

# %%
year21.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2021      Finland  Western Europe            7.842
# 1     2  2021      Denmark  Western Europe            7.620
# 2     3  2021  Switzerland  Western Europe            7.571
# 3     4  2021      Iceland  Western Europe            7.554
# 4     5  2021  Netherlands  Western Europe            7.464
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.446                    1.106
# 1                     1.502                    1.108
# 2                     1.566                    1.079
# 3                     1.482                    1.172
# 4                     1.501                    1.079
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.741                   0.691
# 1                     0.763                   0.686
# 2                     0.816                   0.653
# 3                     0.772                   0.698
# ...

# %% [markdown]
# ## 3. Merging Dataframes

# %%
df_years = (year15, year16, year17, year18, year19, year20, year21)

# %%
df_merged = pd.concat(df_years)

# %%
df_merged.head()
# Out:
#    RANK  Year      Country          Region  Happiness Score  \
# 0     1  2015  Switzerland  Western Europe            7.587
# 1     2  2015      Iceland  Western Europe            7.561
# 2     3  2015      Denmark  Western Europe            7.527
# 3     4  2015       Norway  Western Europe            7.522
# 4     5  2015       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.397                    1.350
# 1                     1.302                    1.402
# 2                     1.325                    1.361
# 3                     1.459                    1.331
# 4                     1.326                    1.323
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.941                   0.666
# 1                     0.948                   0.629
# 2                     0.875                   0.649
# 3                     0.885                   0.670
# ...

# %%
#Exporting to ensure merge successful in Excel 
df_merged.to_csv(os.path.join(path, 'Data', 'Prepared Data', '2Merged_dataset.csv'), index=False)

# %% [markdown]
# ## 4. Data Cleaning

# %%
#Importing clean/merged dataset
df = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', '2Merged_dataset.csv'), index_col = False)

# %%
df
# Out:
#       RANK  Year      Country              Region  Happiness Score  \
# 0        1  2015  Switzerland      Western Europe            7.587
# 1        2  2015      Iceland      Western Europe            7.561
# 2        3  2015      Denmark      Western Europe            7.527
# 3        4  2015       Norway      Western Europe            7.522
# 4        5  2015       Canada       North America            7.427
# ...    ...   ...          ...                 ...              ...
# 1079   145  2021      Lesotho  Sub-Saharan Africa            3.512
# 1080   146  2021     Botswana  Sub-Saharan Africa            3.467
# 1081   147  2021       Rwanda  Sub-Saharan Africa            3.415
# 1082   148  2021     Zimbabwe  Sub-Saharan Africa            3.145
# 1083   149  2021  Afghanistan          South Asia            2.523
#
#       Economy (GDP per Capita)  Family (Social Support)  \
# 0                        1.397                    1.350
# ...

# %%
#Checking dataframe rows and columns 
df.shape
# Out:
# (1084, 12)

# %%
# Renaming RANK column for 
df.rename(columns = {'RANK' : 'Country Rank'}, inplace = True)

# %%
#Checking for nulls 
df.isnull().sum()
# Out:
# Country Rank                         0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# Dystopia Residual                    0
# dtype: int64

# %%
#Checking for duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Country Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity), Dystopia Residual]
# Index: []

# %% [markdown]
# ## 5. Descriptive Statistics

# %%
#Descriptive Statistics 
df.describe()
# Out:
#        Country Rank         Year  Happiness Score  Economy (GDP per Capita)  \
# count   1084.000000  1084.000000      1084.000000               1084.000000
# mean      77.950185  2017.968635         5.413462                  0.917772
# std       44.766196     1.995594         1.118597                  0.402918
# min        1.000000  2015.000000         2.523000                  0.000000
# 25%       39.000000  2016.000000         4.571000                  0.613500
# 50%       78.000000  2018.000000         5.385000                  0.982000
# 75%      117.000000  2020.000000         6.215750                  1.238750
# max      158.000000  2021.000000         7.842000                  2.096000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count              1084.000000               1084.000000
# mean                  1.050102                  0.611094
# std                   0.332027                  0.248612
# ...

# %%
#Checking for mixed-type columns 
df.dtypes
# Out:
# Country Rank                           int64
# Year                                   int64
# Country                               object
# Region                                object
# Happiness Score                      float64
# Economy (GDP per Capita)             float64
# Family (Social Support)              float64
# Health (Life Expectancy)             float64
# Freedom (Life Choices)               float64
# Trust (Government Corruption)        float64
# Generosity (Donations to Charity)    float64
# Dystopia Residual                    float64
# dtype: object

# %% [markdown]
# ## 6. Exporting Cleaned Dataframe

# %%
df.to_csv(os.path.join(path, 'Data', 'Prepared Data', '2Cleaned_dataset.csv'), index=False)
